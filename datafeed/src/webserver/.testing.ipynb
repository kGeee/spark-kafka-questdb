# %%
import httpx, asyncio, os
import json 


with open('queries.json') as f: queries = json.load(f)

url = os.environ.get('URL',"provider.pcgameservers.com")
port = os.environ.get('PORT', 30278)
query = 'select * from binance_liquidations'
timeout=httpx.Timeout(10, read=15.0)
with httpx.AsyncClient(timeout=timeout) as client:
    resp = await client.get(f"http://{url}:{port}/exec", params={'query': query})

print(json.loads(resp.text))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 11
#       9 query = 'select * from binance_liquidations'
#      10 timeout=httpx.Timeout(10, read=15.0)
# ---> 11 with httpx.AsyncClient(timeout=timeout) as client:
#      12     resp = await client.get(f"http://{url}:{port}/exec", params={'query': query})
#      14 print(json.loads(resp.text))
#
# TypeError: 'AsyncClient' object does not support the context manager protocol

# %%
# Out:
# Collecting httpx
#   Using cached httpx-0.24.1-py3-none-any.whl (75 kB)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.11/site-packages (from httpx) (2023.5.7)
# Collecting httpcore<0.18.0,>=0.15.0
#   Downloading httpcore-0.17.3-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 228.2 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: idna in /opt/homebrew/lib/python3.11/site-packages (from httpx) (3.4)
# Collecting sniffio
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting h11<0.15,>=0.13
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting anyio<5.0,>=3.0
#   Downloading anyio-4.0.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 908.5 kB/s eta 0:00:000:010m
# Installing collected packages: sniffio, h11, anyio, httpcore, httpx
# Successfully installed anyio-4.0.0 h11-0.14.0 httpcore-0.17.3 httpx-0.24.1 sniffio-1.3.0
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
import math
def multiply(num1: str, num2: str) -> str:
    l1,l2 = len(num1), len(num2)
    res = 0
    # 100*400+3*400+20*400+123*50+123*6
    for i, val in enumerate(num1):
        first_list_val = int(int(val) * math.pow(10, l1-i-1))
        for j, val2 in enumerate(num2):
            second_list_val = int(int(val2) * math.pow(10, l2-j-1))
            res += first_list_val*second_list_val
    return str(res)
            
multiply("123", "456")
# Out:
# '56088'

# %%
import openai
from bs4 import BeautifulSoup
import requests

# Define your OpenAI GPT-3 API key
api_key = "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"


# Send an HTTP request to the URL
url = 'https://docs.automationanywhere.com/bundle/enterprise-v2019/page/enterprise-cloud/topics/security-architecture/cloud-automation-anywhere-enterprise-overview.html'
response = requests.get(url)

# Sample web page content
web_page_content = """
<html>
<head>
    <title>Sample Web Page</title>
</head>
<body>
    <h1>Welcome to our website</h1>
    <p>This is a sample web page.</p>
    <div class="main-content">
        <h2>About Us</h2>
        <p>We are a company that specializes in...</p>
    </div>
    <div class="contact-info">
        <h2>Contact Information</h2>
        <address>
            <strong>Email:</strong> contact@example.com<br>
            <strong>Phone:</strong> 123-456-7890
        </address>
    </div>
</body>
</html>
"""

# Parse the HTML content of the page
soup = BeautifulSoup(response.text, 'html.parser')

# remove useless tags
def remove_tags(tags=['style', 'script', 'nav']):
    for data in soup(tags):
        data.decompose()

remove_tags()
body_content = soup.find('body')
# p_elements = soup.find_all('p')
# table_elements = soup.find_all('table')
print(body_content)

# Use GPT-3 to extract relevant information
def extract_information(content):
    prompt = f"Extract relevant information from the following web page:\n{content}"
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[{'role': "user", 'content': prompt}],
        max_tokens=1500,  # Adjust the max_tokens as needed
        api_key=api_key
    )
    return response

# Extract information from the sample web page
extracted_data = extract_information(body_content)

# Display the extracted data
print(f"Extracted Data using {extracted_data['usage']['total_tokens']} tokens")
print(extracted_data['choices'][0]['message']['content'])
# Out:
# <body>
# <div id="root" tabindex="-1"><div class="zDocsLayout"><div class="zDocsSkipToElement" id="zDocsSkipToElement"><a href="#content">Skip to main content</a><a href="#search">Skip to search</a></div><div></div><div class="zDocsHeader" id="zDocsHeader"></div><main class="zDocsMain"><div id="content" tabindex="-1"><section class="zDocsSubHeader" id="zDocsSubHeader"><div class="zDocsSubHeaderBreadcrumbsContainer"><div class="zDocsBreadcrumbs"><h2 class="zDocsBreadcrumbsLastItem">Automation 360</h2></div></div><div class="zDocsSubHeaderSearchBoxContainer"><form autocomplete="off" class="zDocsSearchBox zDocsSubHeaderSearchBox" data-testid="zDocsSearchBox"><div class="zDocsSearchBoxContainer"><div class="zDocsSearchBoxInputGroup"><div class="right zDocsSearchBoxSubmitButton"><button aria-label="Search Product Documentation" type="submit"><svg class="ico-search"><use xlink:href="#ico-search"></use></svg></button></div><input aria-autocomplete="list" aria-expanded="false" aria-haspopup="listbox" aria-label="Search Product Documentation" class="zDocsSearchBoxInput" id="search" placeholder="Search Product Documentation" role="combobox" type="text" value=""/><div aria-expanded="false" aria-label="Show search tips" class="zDocsSearchTips" role="button" tabindex="0"><div><svg aria-hidden="true" class="ico-info-circle-empty"><use xlink:href="#ico-info-circle-empty"></use></svg></div></div></div></div></form></div></section><div class="contentPlaceholder" style="height:0"><div class="contentContainer undefined"><div class="zDocsStickyTitle" id="zDocsStickyTitle"><div class="zDocsTopicPage"><h1>Automation 360</h1><div class="zDocsTopicActions"><div class="zDocsBundlePagination" data-testid="next-prev-container"><div class="zDocsPrevTopicButton zDocsPrevTopicButton"><span class="disabledPagination"><a aria-current="page" aria-label="" class="active" data-tooltip-content="" data-tooltip-id="zDocsTopicActionsTooltipSticky" data-tooltip-open="false" href="/"><svg aria-hidden="true" class="ico-prev"><use xlink:href="#ico-prev"></use></svg></a></span></div><div class="zDocsNextTopicButton zDocsNextTopicButton"><span class="disabledPagination"><a aria-current="page" aria-label="" class="active" data-tooltip-content="" data-tooltip-id="zDocsTopicActionsTooltipSticky" data-tooltip-open="false" href="/"><svg aria-hidden="true" class="ico-next"><use xlink:href="#ico-next"></use></svg></a></span></div></div><div class="zDocsExportPdfMenu zDocsExportMenu"><span aria-expanded="false" aria-label="Download as PDF" class="d-none d-lg-flex" data-toggle="dropdown" data-tooltip-content="Download as PDF" data-tooltip-id="zDocsTopicActionsTooltipSticky" role="button" tabindex="0"><svg aria-hidden="true" class="ico-pdf"><use xlink:href="#ico-pdf"></use></svg></span><span class="d-lg-none d-flex" data-return-focus="#zDocsTopicActionsMobile-sticky" data-target="#ZdExportPDFModal" data-toggle="modal" role="button" tabindex="0"><svg aria-hidden="true" class="ico-pdf"><use xlink:href="#ico-pdf"></use></svg>Download as PDF</span><div class="dropdown-menu zDocsDropdownMenu undefined"><a class="zDocsExportItem zDocsExportTopicButton" href="#" id="singlePdf-sticky" role="button">Save selected topic</a><a class="zDocsExportItem zDocsExportSubtopicsButton" href="#" id="pdfWithChildren-sticky" role="button">Save selected topic and subtopics</a><a class="zDocsExportItem zDocsExportBundleButton" href="#" id="wholeBundlePdf-sticky" role="button">Save all topics</a></div></div><div class="zDocsTopicShare zDocsShareButton"><span aria-expanded="false" aria-label="Share" class="d-none d-lg-flex zDocsShareDialogButton" data-toggle="dropdown" data-tooltip-content="Share" data-tooltip-id="zDocsTopicActionsTooltipSticky" role="button" tabindex="0"><svg aria-hidden="true" class="ico-share"><use xlink:href="#ico-share"></use></svg></span><span class="d-lg-none zDocsShareDialogButton" role="button" tabindex="0"><svg aria-hidden="true" class="ico-share"><use xlink:href="#ico-share"></use></svg>S ...
# <h1 class="title topictitle1" id="ariaid-title1">
# <span class="ph">Automation 360</span>
# </h1>
# <div class="body conbody"><p class="shortdesc">The <span class="ph">Automation Anywhere</span> Digital Workforce platform is the foundation to deliver the
#         automation of complex business work securely and at scale. <span class="ph">Automation 360</span> is
#         an industry-leading RPA and digital workforce platform that combines an easy-to-use user
#         interface with enterprise-class reliability and the security to enable real-time
#         self-automation.</p>
# <section class="section"><h2 class="title sectiontitle" id="d759935e133">Overview</h2>
# <p class="p">
# <span class="ph">Automation 360</span> is an industry-leading RPA and digital workforce
#                 platform that combines an easy-to-use user interface with enterprise-class
#                 reliability and the security to enable real-time self-automation. It delivers a
#                 browser-based, intuitive experience for business users to quickly automate tasks and
#                 tools for developers to build process automation. <span class="ph">Automation 360</span>
#                 provides both <span class="ph">On-Premises</span> and <span class="ph">Cloud</span> deployment
#                 options and is the first platform that provides RPA-as-a-Service as an automation
#                 solution. It enables users to automate applications across different infrastructures
#                 and industries such as banking, telecommunications, and business process outsourcing
#                 (BPO) organizations.</p>
# <div class="p">
# <span class="ph">Automation 360</span> provides capabilities such as the following:<ul class="ul">
# <li class="li">An intuitive interface to create a <span class="ph">bot</span> and design business
#                         process automation workflows.</li>
# <li class="li">Support for multiple operating systems including Windows, Linux, and
#                         MacOS.</li>
# <li class="li">Different views of <span class="ph">bot</span> to facilitate collaboration: flow view
#                         for business users, list view for developers, and dual view for
#                         collaboration.</li>
# <li class="li">Recorder that works across various platforms such as Microsoft Windows,
#                         Citrix, Web, and SAP.</li>
# <li class="li">Advanced variables capabilities and support for <span class="ph">JavaScript</span>, <span class="ph">Python</span>, and <span class="ph">VBScript</span>.</li>
# <li class="li">A flexible architecture that enables you to add new packages.</li>
# </ul>
# </div>
# <p class="p">The platform also includes attended automation and plug-ins that enable business
#                 users to automate tasks from within their business applications such as Microsoft
#                 Excel and Salesforce. This capability makes automation of front-office processes
#                 easier, faster, and more cost-efficient.</p>
# <p class="p">
# <span class="ph">Automation 360</span> is available globally and in 10 languages, including
#                 English, French, German, Japanese, Korean, Italian, Portuguese, Russian, Spanish,
#                 Simplified Chinese, and Traditional Chinese.</p>
# </section>
# <section class="section"><h2 class="title sectiontitle" id="d759935e206">
# <span class="ph">Automation 360</span> components</h2>
# <dl class="dl">
# <dt class="dt dlterm">
# <span class="ph">Automation Co-Pilot for Business Users</span> (<span class="ph">Automation Co-Pilot</span>)</dt>
# <dd class="dd">
# <span class="ph">Automation Co-Pilot</span> is an easy-to-use interface that enables
#                         business users to collaborate with <span class="ph">bots</span>. Users can start
#                         process automations, provide feedback to <span class="ph">bots</span> to resume
#                         processes, and escalate requests to additional users for downstream
#                         processing. <span class="ph">Automation Co-Pilot</span> enables the enterprise to unlock
#                         new automation opportunities between humans and <span class="ph">bots</span> that RPA
#                         could not previously address.<p class="p">
# <a class="xref" data-bundleid="enterprise-v2019" data-navpath="enterprise-cloud/topics/aae-architecture-implementation/aari-introduction-components.html" href="/bundle/enterprise-v2019/page/enterprise-cloud/topics/security-architecture/../aae-architecture-implementation/aari-introduction-components.html" title="Automation Co-Pilot for Business Users provides a simple, front-end interface for users to execute and interact with bots and applications.">Automation Co-Pilot for Business Users (previously named AARI)</a>
# </p>
# </dd>
# <dt class="dt dlterm">
# <span class="ph">Automation Workspace</span>
# </dt>
# <dd class="dd">(formerly known as RPA Workspace) A web-based workspace that
#                   provides the tools and capabilities to create, upload, and deploy <span class="ph">bots</span> to automate repetitive tasks and processes. It
#                   includes the following: <ul class="ul" id="icc1682768205700__ul_fpc_td3_qqb">
# <li class="li">
# <span class="ph">Control Room</span>
# </li>
# <li class="li">
# <span class="ph">Bot Runner</span>
# </li>
# <li class="li">
# <span class="ph">Bot editor</span>
# </li>
# <li class="li">
# <span class="ph">Bot Creator</span>
# </li>
# <li class="li">
# <span class="ph">Credential Vault</span>
# </li>
# </ul>
# </dd>
# <dd class="dd ddexpand">
# <span class="ph">Automation Workspace</span> provides the following capabilities:<ul class="ul" id="icc1682768205700__ul_az5_ymt_kqb">
# <li class="li">Enables users to manage, schedule, and execute <span class="ph">bots</span>
# </li>
# <li class="li">Enables user management through <span class="ph">Active Directory</span> role mapping</li>
# <li class="li">Enables users to manage large number of <span class="ph">Work Items</span>
#                                 through workload management</li>
# </ul>
# </dd>
# <dt class="dt dlterm">
# <span class="ph">Process Discovery</span>
# </dt>
# <dd class="dd">An intelligent business solution that delivers a real-time, data-driven map
#                         of your business to help you uncover transformational process insights
#                         across all applications, through each department, and for every single task.
#                             <span class="ph">Process Discovery</span> follows the human instead of process
#                         logs by using advanced computer vision, machine learning, and artificial
#                         intelligence to capture every step in every process across every system. It
#                         requires zero integration, is universally compatible, and provides the
#                         privacy and security of an on-premises solution.</dd>
# <dt class="dt dlterm" id="icc1682768205700__peg-overview">Privacy Enhanced Gateway</dt>
# <dd class="dd">Using Privacy Enhanced Gateway (PEG), enterprises can confidently execute on
#                         their strategic business initiatives by filtering their sensitive data in a
#                         secure and scalable manner. PEG works by redacting sensitive data that has
#                         been obtained on customer's machines within their own network before
#                         forwarding the data to the <span class="ph">Process Discovery</span> cloud for
#                         analysis. As all traffic from the agents goes through PEG before leaving the
#                         customer's perimeter, PEG removes personally identifiable information (PII)
#                         and sensitive data.<p class="p">
# <a class="xref" data-bundleid="enterprise-v2019" data-navpath="discovery-bot/topics/getting-started-with-privacy-enhanced-gateway.html" href="/bundle/enterprise-v2019/page/enterprise-cloud/topics/security-architecture/../../../discovery-bot/topics/getting-started-with-privacy-enhanced-gateway.html" title="Control the data that the Process Discovery cloud platform receives by using the Process Discovery Privacy Enhanced Gateway (PEG). PEG redacts sensitive data that is included in video frames collected by the Process Discovery desktop sensor. This redaction occurs within your own Virtual Private Cloud (VPC) before the data is forwarded to the Process Discovery cloud for analysis.">Getting started with Privacy Enhanced Gateway</a>
# </p>
# </dd>
# <dt class="dt dlterm">
# <span class="ph">Discovery Bot</span>
# </dt>
# <dd class="dd">An intelligent business solution for enterprise businesses that provides
#                         capabilities for end users to discover opportunities for automation using
#                         process discovery. <span class="ph">Discovery Bot</span> focuses on process
#                         automation by capturing document processes, identifying opportunities from
#                         business centric processes, and prioritizing opportunities based on ROI, and
#                         create <span class="ph">bots</span> automatically. <span class="ph">Discovery Bot</span>
#                         aligns business workers to uncover automation opportunities that can
#                         optimize the return on your RPA investment. <p class="p">
# <a class="xref" data-bundleid="enterprise-v2019" data-navpath="discovery-bot/topics/discovery-bot-intro.html" href="/bundle/enterprise-v2019/page/enterprise-cloud/topics/security-architecture/../../../discovery-bot/topics/discovery-bot-intro.html" title="You can use Discovery Bot to identify the processes in your business that can be automated. Discovery Bot identifies such processes by recording and analyzing user interactions with various systems for processes, comparing the potential ROI from automating these processes, and creating bots to automate the processes.">Process discovery by using Discovery Bot</a>
# </p>
# </dd>
# <dt class="dt dlterm">
# <span class="ph">IQ Bot</span>
# </dt>
# <dd class="dd">An intelligent document processing solution that can read and process
#                         various complex documents and emails. <span class="ph">IQ Bot</span> combines RPA
#                         with multiple AI techniques to intelligently capture, classify, and extract
#                         semi-structured and unstructured data, allowing document-centric business
#                         processes to be automated end-to-end.<p class="p">
# <a class="xref" data-bundleid="enterprise-v2019" data-navpath="enterprise-cloud/topics/iq-bot/cloud-iqb-getting-started.html" href="/bundle/enterprise-v2019/page/enterprise-cloud/topics/security-architecture/../iq-bot/cloud-iqb-getting-started.html" title="This collection of topics guide you through the process of installing or setting up Automation 360 IQ Bot On-Premises and Cloud.">Install and update Automation 360 IQ Bot</a>
# </p>
# </dd>
# <dt class="dt dlterm">
# <span class="ph">Bot Insight</span>
# </dt>
# <dd class="dd">The analytics platform that provides real-time, interactive, and smart
#                         insights about business processes and operational intelligence. <span class="ph">Bot Insight</span> uses the large amount of content-level and
#                         productivity data that the deployed <span class="ph">bots</span> generate and
#                         translates the data into insights through automatically generated and
#                         customizable dashboards.<p class="p">
# <a class="xref" data-bundleid="enterprise-v2019" data-navpath="enterprise-cloud/topics/bot-insight/user/bot-insight-overview.html" href="/bundle/enterprise-v2019/page/enterprise-cloud/topics/security-architecture/../bot-insight/user/bot-insight-overview.html" title="Automation Anywhere Bot Insight processes real-time and interactive insights about business processes, and provides operational intelligence. Access the bots, and manage and instrument them to gather business analytics and insights, and publish dashboards.">Business analytics through Bot Insight</a>
# </p>
# </dd>
# <dt class="dt dlterm">
# <span class="ph">Bot Store</span>
# </dt>
# <dd class="dd">Online marketplace for pre-built <span class="ph">bots</span> and <span class="ph">Digital Workers</span> that run on the <span class="ph">Automation 360</span>
#                         platform. Access <span class="ph">Bot Store</span> directly from the <span class="ph">Control Room</span> to download or submit <span class="ph">bots</span> and
#                             <span class="ph">packages</span>.<p class="p">
# <a class="xref" data-bundleid="enterprise-v2019" data-navpath="enterprise-cloud/topics/control-room/working-with-bot-store/cloud-bot-store-overview.html" href="/bundle/enterprise-v2019/page/enterprise-cloud/topics/security-architecture/../control-room/working-with-bot-store/cloud-bot-store-overview.html" title="You can access Bot Store from the Control Room. From Bot Store, you can download bots or packages to your Control Room repository.">Bot Store</a>
# </p>
# <dl class="dl">
# <dt class="dt dlterm">
# <span class="ph">Private Bot Store</span>
# </dt>
# <dd class="dd">A secure internal <span class="ph">bot</span> marketplace for a company
#                                     to post and share details and documentation for all internally
#                                     developed <span class="ph">bots</span>. Employees can easily discover
#                                     internal <span class="ph">bots</span> and commands to reuse in addition
#                                     to all of <span class="ph">bots</span> bots from the <span class="ph">Automation Anywhere</span>
# <span class="ph">Bot Store</span>.<p class="p">
# <a class="xref" data-bundleid="enterprise-v2019" data-navpath="enterprise-cloud/topics/security-architecture/cloud-private-bot-store-overview.html" href="/bundle/enterprise-v2019/page/enterprise-cloud/topics/security-architecture/cloud-private-bot-store-overview.html" title="Private Bot Store is a secure internal bot marketplace for a company to post and share details and documentation for all internally developed bots. Employees can easily discover internal bots and commands to reuse in addition to all of the bots from the Automation Anywhere Bot Store vendors.">Private Bot Store</a>
# </p>
# </dd>
# </dl>
# </dd>
# </dl>
# <p class="p">The following image shows the components of <span class="ph">Automation 360</span>:</p>
# <img alt="Components of Automation 360 and how the product can be accessed anywhere from any device." class="image" src="https://automationanywhere-be-prod.automationanywhere.com/bundle/enterprise-v2019/page/enterprise-cloud/topics/security-architecture/../../../automation360img.png?_LANG=enus"/>
# </section>
# <section class="section"><h2 class="title sectiontitle" id="d759935e635">Benefits</h2>
# <dl class="dl">
# <dt class="dt dlterm">Faster time to value</dt>
# <dd class="dd">
# <ul class="ul">
# <li class="li">Instant web-based deployment that enables you to start developing
#                                     <span class="ph">bots</span> quickly</li>
# <li class="li">An intuitive interface that enables users with varying skill levels
#                                 to easily use the product and speed up the learning process</li>
# <li class="li">Easy collaboration between business, process, and IT</li>
# </ul>
# </dd>
# <dt class="dt dlterm">Business agility</dt>
# <dd class="dd">
# <ul class="ul">
# <li class="li">Regular updates to stay up-to-date on any device anywhere</li>
# <li class="li">Business continuity with high availability and disaster
#                                 recovery</li>
# <li class="li">Scalability</li>
# </ul>
# </dd>
# <dt class="dt dlterm">Lowest total cost of ownership (TCO)</dt>
# <dd class="dd">
# <ul class="ul">
# <li class="li">No additional infrastructure investment required</li>
# <li class="li">Single platform across front office, back office, and employee
#                                 applications</li>
# <li class="li">Reduced maintenance cost</li>
# </ul>
# </dd>
# </dl>
# </section>
# <section class="section">
# <p class="p">Watch the following video to learn more about RPA:</p>
# <iframe allowfullscreen="allowfullscreen" height="288" src="https://www.youtube.com/embed/MGYbjkg7QhU?" type="youtube" width="512">
# <span>RPA overview</span>
#
#          Â </iframe>
# </section>
# <section class="section" id="icc1682768205700__automation-360-deployment-models"><h2 class="title sectiontitle" id="d759935e722">Deployment models</h2>
# <span class="ph">Automation 360</span> provides the following deployment models:<dl class="dl">
# <dt class="dt dlterm">
# <span class="ph">Cloud</span>
# </dt>
# <dd class="dd">
# <span class="ph">Automation 360</span>
# <span class="ph">Cloud</span>
#                    is hosted by <span class="ph">Automation Anywhere</span>, providing an easy consumption model of the <span class="ph">Automation 360</span> platform built on a cloud-native architecture.
#                         With the <span class="ph">Automation 360</span>
# <span class="ph">Cloud</span> service, the <span class="ph">Automation 360</span>
#                         platform, which includes the <span class="ph">Automation 360</span>
# <span class="ph">Control Room</span> and applications (<span class="ph">Automation Workspace</span>,
#                             <span class="ph">IQ Bot</span>, <span class="ph">Bot Insight</span>, <span class="ph">Automation Co-Pilot</span>, and <span class="ph">Discovery Bot</span>), is hosted
#                         by <span class="ph">Automation Anywhere</span> and accessed by users through a web browser. The <span class="ph">Bot Agent</span> devices where the <span class="ph">bots</span> run and
#                         execute the automations remain on the customer's infrastructure and securely
#                         connect to the <span class="ph">Automation 360</span>
# <span class="ph">Cloud</span> service through HTTPS.
#                         </dd>
# <dt class="dt dlterm">Cloud-enabled</dt>
# <dd class="dd">In this deployment model, data is
#                         hosted <span class="ph">On-Premises</span>. This model is suitable for customers
#                         who have to adhere to strict regulatory norms where data sovereignty is
#                         mandatory.</dd>
# <dt class="dt dlterm">
# <span class="ph">On-Premises</span> with packages updates through <span class="ph">Cloud</span>
# </dt>
# <dd class="dd">With <span class="ph">Automation Anywhere</span>
# <span class="ph">On-Premises</span> with packages updates through <span class="ph">Cloud</span> service, all business, personal, and operational
#                         data is kept on and deployed from the server on-premises on the customer
#                         network.</dd>
# </dl>
# <p class="p">The following
#                 image shows the deployment models for <span class="ph">Automation 360</span>:</p>
# <img alt="Deployment models available in Automation 360 and how the control room, data, and updates work for each model" class="image" src="https://automationanywhere-be-prod.automationanywhere.com/bundle/enterprise-v2019/page/enterprise-cloud/topics/security-architecture/../../../deploymentmodels.png?_LANG=enus" width="800"/>
# <p class="p">See also <a class="xref" data-bundleid="enterprise-v2019" data-navpath="enterprise-cloud/topics/security-architecture/cloud-data-mapping.html" href="/bundle/enterprise-v2019/page/enterprise-cloud/topics/security-architecture/cloud-data-mapping.html" title="Learn about secure deployment models, data element locations, and operational responsibilities.">Cloud operational responsibilities</a>.</p>
# </section>
# <section class="section" id="icc1682768205700__section_ilb_wfr_tkb"><h2 class="title sectiontitle" id="d759935e866">Available offerings</h2>
# <div class="p">The <span class="ph">Automation 360</span> platform includes the following offerings:<ul class="ul" id="icc1682768205700__ul_phf_yfr_tkb">
# <li class="li">
# <span class="ph">Automation 360</span> delivered in the cloud, hosted by <span class="ph">Automation Anywhere</span> with no client installation or additional infrastructure
#                         required</li>
# <li class="li">
# <span class="ph">Automation 360</span>, the full platform delivered <span class="ph">On-Premises</span>
# </li>
# <li class="li">
# <span class="ph">Community Edition</span>, a free web-based option for users to
#                         experience a wide-range of <span class="ph">Automation 360</span>
# <span class="ph">bot</span> creation capabilities</li>
# </ul>
# </div>
# </section>
# <section class="section" id="icc1682768205700__contextual-help-center">
# <div class="note note note_note" id="icc1682768205700__note_qvy_wvf_yxb"><span class="note__title">Note:</span> For information on the in-product help and
#             guide, see <a class="xref" data-bundleid="enterprise-v2019" data-navpath="resource-center.html" href="/bundle/enterprise-v2019/page/enterprise-cloud/topics/security-architecture/../../../resource-center.html" title="Automation 360 provides in-product assistance through the Resource center widget. The in-product help and guide provides on-demand access to product documentation, walkthroughs, and other guides to help you familiarize with the interface and learn more about the capabilities in the product.">In-product user assistance</a>.</div>
# </section>
# <section class="section"><h2 class="title sectiontitle" id="d759935e926">Documentation on previous releases</h2>
# <p class="p">For documentation on previous versions of our products, see the PDFs available on
#                 these pages:</p>
# <ul class="ul">
# <li class="li">
# <a class="xref" href="https://docs.automationanywhere.com/bundle/aae-support-docs/page/topics/aae-client/support/A2019-release-documentation.html" target="_blank">Automation 360</a>
# </li>
# <li class="li">
# <a class="xref" href="https://docs.automationanywhere.com/bundle/aae-support-docs/page/topics/aae-client/support/support-docs_additional_documents.html" target="_blank">Enterprise 11.x</a>
# </li>
# <li class="li">
# <a class="xref" href="https://docs.automationanywhere.com/bundle/aae-support-docs/page/topics/aae-client/support/FIQ-release-documentation.html" target="_blank">Process Discovery</a>
# </li>
# <li class="li">
# <a class="xref" href="https://docs.automationanywhere.com/bundle/aae-support-docs/page/topics/aae-client/support/AARI-release-documentation.html" target="_blank">Integrations</a>
# </li>
# <li class="li">
# <a class="xref" href="https://docs.automationanywhere.com/bundle/aae-support-docs/page/topics/aae-client/support/support-docs_documents.html" target="_blank">IQ Bot 11x</a>
# </li>
# <li class="li">
# <a class="xref" href="https://docs.automationanywhere.com/bundle/aae-support-docs/page/topics/aae-client/support/mobile-app-release-documentation.html" target="_blank">Mobile apps</a>
# </li>
# <li class="li">
# <a class="xref" href="https://docs.automationanywhere.com/bundle/aae-support-docs/page/topics/aae-client/support/human-bot-collaboration.html" target="_blank">Human-Bot Collaboration 11.x</a>
# </li>
# </ul>
# </section>
# </div>
# </article></main></article>
# </div></div><div class="contentPlaceholder" style="height:0"><div class="contentContainer zDocsSideBoxes undefined"><div><h5 aria-level="4">Related Content</h5><ul><li><a href="https://university.automationanywhere.com"><svg aria-hidden="true" class="ico-related-link"><use xlink:href="#ico-related-link"></use></svg> <!-- -->Automation Anywhere University: RPA Training and Certification (A-People login required)</a></li><li><a href="https://www.automationanywhere.com/solutions/bpo"><svg aria-hidden="true" class="ico-related-link"><use xlink:href="#ico-related-link"></use></svg> <!-- -->RPA for Business Process Outsourcing (BPO)</a></li><li><a href="https://developer.automationanywhere.com/learn/bot-developer-journey/what-is-rpa"><svg aria-hidden="true" class="ico-related-link"><use xlink:href="#ico-related-link"></use></svg> <!-- -->What are RPA bots</a></li><li><a href="https://www.automationanywhere.com/rpa/robotic-process-automation"><svg aria-hidden="true" class="ico-related-link"><use xlink:href="#ico-related-link"></use></svg> <!-- -->What is RPA?</a></li><li><a href="https://www.automationanywhere.com/products/enterprise"><svg aria-hidden="true" class="ico-related-link"><use xlink:href="#ico-related-link"></use></svg> <!-- -->Automation 360 platform</a></li></ul></div></div></div></div><div class="bottomFeedback"><div class="bottomFeedbackContent"><span class="bottomFeedbackText">Was this topic helpful?</span><div class="bottomFeedbackButtonGroup"><a data-target="#feedbackModal_bottom_15597449" data-toggle="modal" href="#" role="button" type="button"><svg aria-hidden="true" class="ico-thumbs-up"><use xlink:href="#ico-thumbs-up"></use></svg><span>Like</span></a><a data-target="#feedbackModal_bottom_15597449" data-toggle="modal" href="#" role="button" type="button"><svg aria-hidden="true" class="ico-thumbs-down"><use xlink:href="#ico-thumbs-down"></use></svg><span>Dislike</span></a></div></div></div><div style="position:fixed;bottom:90px;right:70px;cursor:pointer;transition-duration:0.2s;transition-timing-function:linear;transition-delay:0s;z-index:3;opacity:0;visibility:hidden;transition-property:opacity, visibility"><button aria-label="Scroll to top" class="zDocsScrollTopBtn" data-tooltip-content="Scroll to top" data-tooltip-id="zDocsBackToTopToolTip" id="zDocsScrollToTop" type="button"><svg aria-hidden="true" class="ico-next"><use xlink:href="#ico-next"></use></svg></button></div></article></div></div></div></main><footer class="zDocsFooter" id="footer" role="contentinfo"><div class="subFooter"><h2>Go be great.</h2><p>Automation Anywhere empowers people whose ideas, thought and focus make the companies they work for great. We deliver the worldâs most sophisticated Digital Workforce Platform making work more human by automating business processes and liberating people.</p></div><div class="section"><a href="/"><img alt="Automation Anywhere Documentation" src="/assets/img/logo-white.svg?6a506ca8bc342c49bb5e"/></a><ul class="socials"><li><a aria-label="facebook" href="https://www.facebook.com/AutomationAnywhereSoftware" rel="noopener noreferrer" target="_blank"><svg aria-hidden="true"><use xlink:href="#ico-facebook"></use></svg></a></li><li><a aria-label="twitter" href="https://twitter.com/AutomationAnywh" rel="noopener noreferrer" target="_blank"><svg aria-hidden="true"><use xlink:href="#ico-twitter"></use></svg></a></li><li><a aria-label="linkedin" href="https://www.linkedin.com/company/automation-anywhere" rel="noopener noreferrer" target="_blank"><svg aria-hidden="true"><use xlink:href="#ico-linkedin"></use></svg></a></li><li><a aria-label="youtube" href="https://www.youtube.com/automationanywhere" rel="noopener noreferrer" target="_blank"><svg aria-hidden="true"><use xlink:href="#ico-youtube"></use></svg></a></li><li><a aria-label="instagram" href="https://www.instagram.com/automation_anywhere/" rel="noopener noreferrer" target="_blank"><svg aria-hidden="true"><use xlink:href="#ico-instagram"></use></svg></a></li><l ...
# <!-- Search Unify autocomplete script -->
#
# </body>
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[30], line 59
#      56     return response
#      58 # Extract information from the sample web page
# ---> 59 extracted_data = extract_information(body_content)
#      61 # Display the extracted data
#      62 print(f"Extracted Data using {extracted_data['usage']['total_tokens']} tokens")
#
# Cell In[30], line 50, in extract_information(content)
#      48 def extract_information(content):
#      49     prompt = f"Extract relevant information from the following web page:\n{content}"
# ---> 50     response = openai.ChatCompletion.create(
#      51         model="gpt-3.5-turbo",
#      52         messages=[{'role': "user", 'content': prompt}],
#      53         max_tokens=1500,  # Adjust the max_tokens as needed
#      54         api_key=api_key
#      55     )
#      56     return response
#
# File /opt/homebrew/lib/python3.11/site-packages/openai/api_resources/chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File /opt/homebrew/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File /opt/homebrew/lib/python3.11/site-packages/openai/api_requestor.py:230, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     209 def request(
#     210     self,
#     211     method,
#    (...)
#     218     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     219 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     220     result = self.request_raw(
#     221         method.lower(),
#     222         url,
#    (...)
#     228         request_timeout=request_timeout,
#     229     )
# --> 230     resp, got_stream = self._interpret_response(result, stream)
#     231     return resp, got_stream, self.api_key
#
# File /opt/homebrew/lib/python3.11/site-packages/openai/api_requestor.py:624, in APIRequestor._interpret_response(self, result, stream)
#     616     return (
#     617         self._interpret_response_line(
#     618             line, result.status_code, result.headers, stream=True
#     619         )
#     620         for line in parse_stream(result.iter_lines())
#     621     ), True
#     622 else:
#     623     return (
# --> 624         self._interpret_response_line(
#     625             result.content.decode("utf-8"),
#     626             result.status_code,
#     627             result.headers,
#     628             stream=False,
#     629         ),
#     630         False,
#     631     )
#
# File /opt/homebrew/lib/python3.11/site-packages/openai/api_requestor.py:687, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     685 stream_error = stream and "error" in resp.data
#     686 if stream_error or not 200 <= rcode < 300:
# --> 687     raise self.handle_error_response(
#     688         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     689     )
#     690 return resp
#
# RateLimitError: Rate limit reached for default-gpt-3.5-turbo in organization org-EBC3B0zOToIe09P9syeVZC6F on tokens per min. Limit: 90000 / min. Current: 0 / min. Contact us through our help center at help.openai.com if you continue to have issues.

# %%
body_content
# Out:
# <body>
# <h1>Welcome to our website</h1>
# <p>This is a sample web page.</p>
# <div class="main-content">
# <h2>About Us</h2>
# <p>We are a company that specializes in...</p>
# </div>
# <div class="contact-info">
# <h2>Contact Information</h2>
# <address>
# <strong>Email:</strong> contact@example.com<br/>
# <strong>Phone:</strong> 123-456-7890
#         </address>
# </div>
# </body>

# %%
from bs4 import BeautifulSoup
import requests

# Send an HTTP request to the URL
url = 'https://support.apple.com/guide/iphone/intro-to-carplay-iphf33a514c9/ios'
response = requests.get(url)

# Parse the HTML content of the page
soup = BeautifulSoup(response.text, 'html.parser')
# remove useless tags
def remove_tags(tags=['style', 'script', 'nav', 'path', 'use','svg', 'button', 'li']):
    for data in soup(tags):
        data.decompose()

remove_tags()
body_content = soup.find('body') #, attrs={'role': 'main'})
print(body_content)
# Out:
# <body class="ac-gn-current-support no-js AppleTopic apd-topic dark-mode-enabled" data-designversion="2" data-istaskopen="true" dir="ltr" itemscope="" itemtype="https://schema.org/TechArticle" lang="en">
# <meta content="S2A49YFKJF2JAT22K" name="globalnav-store-key"/> <meta content="q" name="globalnav-search-field[name]"/> <meta content="https://support.apple.com/kb/index" name="globalnav-search-field[action]"/> <meta content="globalnav_support" name="globalnav-search-field[src]"/> <meta content="organic" name="globalnav-search-field[type]"/> <meta content="search" name="globalnav-search-field[page]"/> <meta content="en_US" name="globalnav-search-field[locale]"/> <meta content="Search Support" name="globalnav-search-field[placeholder]"/> <link href="https://www.apple.com/api-www/global-elements/global-header/v1/assets/globalheader.css" rel="stylesheet" type="text/css"> <div class="globalnav-scrim globalheader-light" id="globalheader"><aside class="globalmessage-segment" dir="ltr" id="globalmessage-segment" lang="en-US"><ul class="globalmessage-segment-content" data-strings='{"view":"{%STOREFRONT%} Store Home","segments":{"smb":"Business Store Home","eduInd":"Education Store Home","other":"Store Home"},"exit":"Exit"}'></ul></aside><div class="globalnav-curtain" id="globalnav-curtain"></div><div class="globalnav-placeholder" id="globalnav-placeholder"></div></div>
# <div id="arabic-localnav">
# <input class="localnav-menustate" id="localnav-menustate" type="checkbox">
#
# <label class="localnav-curtain" htmlfor="localnav-menustate" id="localnav-curtain"></label>
# </input></div>
# <div class="main" dir="ltr" id="arabic" role="main">
# <section class="book topic-search">
# <div class="book-version-name" id="book-version">
# <section class="nojs-version-name" id="nojs-version-name">
# <div class="nojs-version-name-links">
# <a href="https://support.apple.com/guide/iphone/iphf33a514c9/16.0/ios/16.0"> iOS 16 </a>
# </div>
# <div class="nojs-version-name-links">
# <a href="https://support.apple.com/guide/iphone/iphf33a514c9/15.0/ios/15.0"> iOS 15 </a>
# </div>
# <div class="nojs-version-name-links">
# <a href="https://support.apple.com/guide/iphone/iphf33a514c9/14.0/ios/14.0"> iOS 14 </a>
# </div>
# <div class="nojs-version-name-links">
# <a href="https://support.apple.com/guide/iphone/iphf33a514c9/13.0/ios/13.0"> iOS 13 </a>
# </div>
# <div class="nojs-version-name-links">
# <a href="https://support.apple.com/guide/iphone/iphf33a514c9/12.0/ios/12.0"> iOS 12 </a>
# </div>
# </section>
# <section class="book book-version">
# <label class="form-block-label" for="version-dropdown">
# 		  Select version:
#       </label>
# <div class="form-element">
# <select aria-describedby="helpText" class="form-dropdown" data-ignore-tracking="true" id="version-dropdown">
# <option data-direct-url="https://support.apple.com/guide/iphone/iphf33a514c9/16.0/ios/16.0" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="version" data-ss-analytics-link-component_type="select" data-ss-analytics-link-text="iOS 16" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphf33a514c9/16.0/ios/16.0" selected="">
# 					iOS 16
# 				</option>
# <option data-direct-url="https://support.apple.com/guide/iphone/iphf33a514c9/15.0/ios/15.0" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="version" data-ss-analytics-link-component_type="select" data-ss-analytics-link-text="iOS 15" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphf33a514c9/15.0/ios/15.0">
# 					iOS 15
# 				</option>
# <option data-direct-url="https://support.apple.com/guide/iphone/iphf33a514c9/14.0/ios/14.0" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="version" data-ss-analytics-link-component_type="select" data-ss-analytics-link-text="iOS 14" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphf33a514c9/14.0/ios/14.0">
# 					iOS 14
# 				</option>
# <option data-direct-url="https://support.apple.com/guide/iphone/iphf33a514c9/13.0/ios/13.0" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="version" data-ss-analytics-link-component_type="select" data-ss-analytics-link-text="iOS 13" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphf33a514c9/13.0/ios/13.0">
# 					iOS 13
# 				</option>
# <option data-direct-url="https://support.apple.com/guide/iphone/iphf33a514c9/12.0/ios/12.0" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="version" data-ss-analytics-link-component_type="select" data-ss-analytics-link-text="iOS 12" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphf33a514c9/12.0/ios/12.0">
# 					iOS 12
# 				</option>
# </select>
# <span aria-hidden="true" class="form-icon icon icon-chevrondown"></span>
# </div>
# <div class="none" id="helpText">Modifying this control will update this page automatically</div>
# </section>
# </div>
# <div id="searchBar-container">
# <section class="as-search">
# <div class="as-search-content">
# <div class="row">
# <form action="/kb/index" aria-label="iPhone User Guide" class="as-search-form" data-no-results-hint-text="Hit enter to search" data-quick-links-heading="Quick Links" data-suggested-results-heading="Suggested Searches" data-suggestions-endpoint="https://www.apple.com/search-services/suggestions/" id="as-search-form" method="get" onsubmit="return false;">
# <input name="page" type="hidden" value="search">
# <input id="src" name="src" type="hidden" value="support_book_topic">
# <input id="as-search-locale" name="locale" type="hidden" value="en_US">
# <input name="bookid" type="hidden" value="2b65a2eecdd9154b18b569bbfa9abf33">
# <input name="rurl" type="hidden" value="https://support.apple.com/guide/iphone/intro-to-carplay-iphf33a514c9/ios"/>
# <input name="title" type="hidden" value="iPhone User Guide"/>
# <label class="hidden" for="as-search-input">
#           Search this guide
#         </label>
# <input autocomplete="off" class="as-search-form-input" id="as-search-input" name="query" placeholder="Search this guide" spellcheck="false" type="text" value=""/>
#
#
# </input></input></input></input></form>
# </div>
# <div class="row">
# <div aria-expanded="false" class="as-search-suggestions" id="as-search-suggestions-wrapper">
# <span aria-live="polite" class="hidden" role="status"></span>
# <section class="as-search-results-section as-search-results-section-quicklinks">
# <!-- handlebar template goes here-->
# </section>
# <section class="as-search-results-section-divider-space">
# <!-- handlebar template goes here-->
# </section>
# <section class="as-search-results-section as-search-results-section-suggestions">
# <!-- handlebar template goes here-->
# </section>
# <section class="as-search-results-section-no-results">
# <!-- handlebar template goes here-->
# </section>
# </div>
# </div>
# </div>
# </section>
# </div>
# </section>
# <div id="toc-section-wrapper">
# <div class="toc-container" id="toc-container">
# <div class="book book-toc" id="toc-title-link">
# <a class="icon icon-after icon-pluscircle toggle-toc" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="table of contents" data-ss-analytics-link-component_type="toc" data-ss-analytics-link-text="launch=table of contents" href="https://support.apple.com/guide/iphone/toc" id="toc-link" role="button">
# <span class="toc-link-text">Table of Contents</span>
# </a>
# </div>
# </div>
# </div>
# <div id="toc-hidden-content">
# <div class="modal-content" id="modal-toc-container">
# <h2 class="modal-heading" id="modal-heading">iPhone User Guide</h2>
# <ul class="toc hasIcons">
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/welcome/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Welcome" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/welcome/ios" data-tocid="IPH344652DEF" href="https://support.apple.com/guide/iphone/welcome/ios" id="toc-item-IPH344652DEF">
# <span class="name">Welcome</span>
# </a>
# </li>
# <li>
#
# <ul class="non-leaf-node-children" id="node-children-IPH3EEA745D8">
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/setup-basics-iph9374b7411/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Setup basics" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/setup-basics-iph9374b7411/ios" data-tocid="IPH9374B7411" href="https://support.apple.com/guide/iphone/setup-basics-iph9374b7411/ios" id="toc-item-IPH9374B7411">
# <span class="name">Setup basics</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/make-your-iphone-your-own-iphefb3daa42/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Make your iPhone your own" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/make-your-iphone-your-own-iphefb3daa42/ios" data-tocid="IPHEFB3DAA42" href="https://support.apple.com/guide/iphone/make-your-iphone-your-own-iphefb3daa42/ios" id="toc-item-IPHEFB3DAA42">
# <span class="name">Make your iPhone your own</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/take-great-photos-and-videos-iph9bbc8619e/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Take great photos and videos" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/take-great-photos-and-videos-iph9bbc8619e/ios" data-tocid="IPH9BBC8619E" href="https://support.apple.com/guide/iphone/take-great-photos-and-videos-iph9bbc8619e/ios" id="toc-item-IPH9BBC8619E">
# <span class="name">Take great photos and videos</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/keep-in-touch-with-friends-and-family-iph41060df75/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Keep in touch with friends and family" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/keep-in-touch-with-friends-and-family-iph41060df75/ios" data-tocid="IPH41060DF75" href="https://support.apple.com/guide/iphone/keep-in-touch-with-friends-and-family-iph41060df75/ios" id="toc-item-IPH41060DF75">
# <span class="name">Keep in touch with friends and family</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/share-features-with-your-family-iph023f98729/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Share features with your family" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/share-features-with-your-family-iph023f98729/ios" data-tocid="IPH023F98729" href="https://support.apple.com/guide/iphone/share-features-with-your-family-iph023f98729/ios" id="toc-item-IPH023F98729">
# <span class="name">Share features with your family</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/use-iphone-for-your-daily-routines-iph556acc36f/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Use iPhone for your daily routines" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/use-iphone-for-your-daily-routines-iph556acc36f/ios" data-tocid="IPH556ACC36F" href="https://support.apple.com/guide/iphone/use-iphone-for-your-daily-routines-iph556acc36f/ios" id="toc-item-IPH556ACC36F">
# <span class="name">Use iPhone for your daily routines</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
#
# <ul class="non-leaf-node-children" id="node-children-IPH1AB902D8A">
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/supported-models-iphe3fa5df43/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Supported models" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/supported-models-iphe3fa5df43/ios" data-tocid="IPHE3FA5DF43" href="https://support.apple.com/guide/iphone/supported-models-iphe3fa5df43/ios" id="toc-item-IPHE3FA5DF43">
# <span class="name">Supported models</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-8-iph78859565c/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone 8" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-8-iph78859565c/ios" data-tocid="IPH78859565C" href="https://support.apple.com/guide/iphone/iphone-8-iph78859565c/ios" id="toc-item-IPH78859565C">
# <span class="name">iPhone 8</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-8-plus-iphdd6202981/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone 8 Plus" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-8-plus-iphdd6202981/ios" data-tocid="IPHDD6202981" href="https://support.apple.com/guide/iphone/iphone-8-plus-iphdd6202981/ios" id="toc-item-IPHDD6202981">
# <span class="name">iPhone 8 Plus</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-x-iph72dbdbd42/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone X" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-x-iph72dbdbd42/ios" data-tocid="IPH72DBDBD42" href="https://support.apple.com/guide/iphone/iphone-x-iph72dbdbd42/ios" id="toc-item-IPH72DBDBD42">
# <span class="name">iPhone X</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-xr-iph017302841/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone X&lt;small&gt;R&lt;/small&gt;" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-xr-iph017302841/ios" data-tocid="IPH017302841" href="https://support.apple.com/guide/iphone/iphone-xr-iph017302841/ios" id="toc-item-IPH017302841">
# <span class="name">iPhone X<small>R</small></span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-xs-iphc00446242/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone X&lt;small&gt;S&lt;/small&gt;" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-xs-iphc00446242/ios" data-tocid="IPHC00446242" href="https://support.apple.com/guide/iphone/iphone-xs-iphc00446242/ios" id="toc-item-IPHC00446242">
# <span class="name">iPhone X<small>S</small></span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-xs-max-iphcd2066870/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone X&lt;small&gt;S&lt;/small&gt; Max" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-xs-max-iphcd2066870/ios" data-tocid="IPHCD2066870" href="https://support.apple.com/guide/iphone/iphone-xs-max-iphcd2066870/ios" id="toc-item-IPHCD2066870">
# <span class="name">iPhone X<small>S</small> Max</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-11-iphd690e36d3/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone 11" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-11-iphd690e36d3/ios" data-tocid="IPHD690E36D3" href="https://support.apple.com/guide/iphone/iphone-11-iphd690e36d3/ios" id="toc-item-IPHD690E36D3">
# <span class="name">iPhone 11</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-11-pro-iph1129e876d/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone 11 Pro" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-11-pro-iph1129e876d/ios" data-tocid="IPH1129E876D" href="https://support.apple.com/guide/iphone/iphone-11-pro-iph1129e876d/ios" id="toc-item-IPH1129E876D">
# <span class="name">iPhone 11 Pro</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-11-pro-max-iph3d5195e0c/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone 11 Pro Max" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-11-pro-max-iph3d5195e0c/ios" data-tocid="IPH3D5195E0C" href="https://support.apple.com/guide/iphone/iphone-11-pro-max-iph3d5195e0c/ios" id="toc-item-IPH3D5195E0C">
# <span class="name">iPhone 11 Pro Max</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-se-2nd-generation-iph4b7cbc094/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone SE (2nd generation)" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-se-2nd-generation-iph4b7cbc094/ios" data-tocid="IPH4B7CBC094" href="https://support.apple.com/guide/iphone/iphone-se-2nd-generation-iph4b7cbc094/ios" id="toc-item-IPH4B7CBC094">
# <span class="name">iPhone SE (2nd generation)</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-12-mini-ipha4eb291bf/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone 12 mini" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-12-mini-ipha4eb291bf/ios" data-tocid="IPHA4EB291BF" href="https://support.apple.com/guide/iphone/iphone-12-mini-ipha4eb291bf/ios" id="toc-item-IPHA4EB291BF">
# <span class="name">iPhone 12 mini</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-12-iphae3a2eb71/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone 12" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-12-iphae3a2eb71/ios" data-tocid="IPHAE3A2EB71" href="https://support.apple.com/guide/iphone/iphone-12-iphae3a2eb71/ios" id="toc-item-IPHAE3A2EB71">
# <span class="name">iPhone 12</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-12-pro-iph0fd8610b8/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone 12 Pro" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-12-pro-iph0fd8610b8/ios" data-tocid="IPH0FD8610B8" href="https://support.apple.com/guide/iphone/iphone-12-pro-iph0fd8610b8/ios" id="toc-item-IPH0FD8610B8">
# <span class="name">iPhone 12 Pro</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-12-pro-max-iphc798da0f6/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone 12 Pro Max" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-12-pro-max-iphc798da0f6/ios" data-tocid="IPHC798DA0F6" href="https://support.apple.com/guide/iphone/iphone-12-pro-max-iphc798da0f6/ios" id="toc-item-IPHC798DA0F6">
# <span class="name">iPhone 12 Pro Max</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-13-mini-iph7d116e557/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone 13 mini" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-13-mini-iph7d116e557/ios" data-tocid="IPH7D116E557" href="https://support.apple.com/guide/iphone/iphone-13-mini-iph7d116e557/ios" id="toc-item-IPH7D116E557">
# <span class="name">iPhone 13 mini</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-13-iphff32752d4/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone 13" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-13-iphff32752d4/ios" data-tocid="IPHFF32752D4" href="https://support.apple.com/guide/iphone/iphone-13-iphff32752d4/ios" id="toc-item-IPHFF32752D4">
# <span class="name">iPhone 13</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-13-pro-iph4ce326e9d/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone 13 Pro" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-13-pro-iph4ce326e9d/ios" data-tocid="IPH4CE326E9D" href="https://support.apple.com/guide/iphone/iphone-13-pro-iph4ce326e9d/ios" id="toc-item-IPH4CE326E9D">
# <span class="name">iPhone 13 Pro</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-13-pro-max-iphb58c09dcb/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone 13 Pro Max" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-13-pro-max-iphb58c09dcb/ios" data-tocid="IPHB58C09DCB" href="https://support.apple.com/guide/iphone/iphone-13-pro-max-iphb58c09dcb/ios" id="toc-item-IPHB58C09DCB">
# <span class="name">iPhone 13 Pro Max</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-se-3rd-generation-iph2dd14d492/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone SE (3rd generation)" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-se-3rd-generation-iph2dd14d492/ios" data-tocid="IPH2DD14D492" href="https://support.apple.com/guide/iphone/iphone-se-3rd-generation-iph2dd14d492/ios" id="toc-item-IPH2DD14D492">
# <span class="name">iPhone SE (3rd generation)</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-14-iphfc2d9bc6a/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone 14" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-14-iphfc2d9bc6a/ios" data-tocid="IPHFC2D9BC6A" href="https://support.apple.com/guide/iphone/iphone-14-iphfc2d9bc6a/ios" id="toc-item-IPHFC2D9BC6A">
# <span class="name">iPhone 14</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-14-plus-iph7f9e64962/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone 14 Plus" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-14-plus-iph7f9e64962/ios" data-tocid="IPH7F9E64962" href="https://support.apple.com/guide/iphone/iphone-14-plus-iph7f9e64962/ios" id="toc-item-IPH7F9E64962">
# <span class="name">iPhone 14 Plus</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-14-pro-iph6928b4ea3/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone 14 Pro" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-14-pro-iph6928b4ea3/ios" data-tocid="IPH6928B4EA3" href="https://support.apple.com/guide/iphone/iphone-14-pro-iph6928b4ea3/ios" id="toc-item-IPH6928B4EA3">
# <span class="name">iPhone 14 Pro</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/iphone-14-pro-max-iphed34f9f10/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="iPhone 14 Pro Max" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/iphone-14-pro-max-iphed34f9f10/ios" data-tocid="IPHED34F9F10" href="https://support.apple.com/guide/iphone/iphone-14-pro-max-iphed34f9f10/ios" id="toc-item-IPHED34F9F10">
# <span class="name">iPhone 14 Pro Max</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/whats-new-in-ios-16-iphfed2c4091/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="What’s new in iOS 16" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/whats-new-in-ios-16-iphfed2c4091/ios" data-tocid="IPHFED2C4091" href="https://support.apple.com/guide/iphone/whats-new-in-ios-16-iphfed2c4091/ios" id="toc-item-IPHFED2C4091">
# <span class="name">What’s new in iOS 16</span>
# </a>
# </li>
# <li>
#
# <ul class="non-leaf-node-children" id="node-children-IPH3BF43233">
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/turn-on-and-set-up-iphone-iph1fd7e482f/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Turn on and set up iPhone" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/turn-on-and-set-up-iphone-iph1fd7e482f/ios" data-tocid="IPH1FD7E482F" href="https://support.apple.com/guide/iphone/turn-on-and-set-up-iphone-iph1fd7e482f/ios" id="toc-item-IPH1FD7E482F">
# <span class="name">Turn on and set up iPhone</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/wake-and-unlock-iph5a0b5b9c5/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Wake and unlock" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/wake-and-unlock-iph5a0b5b9c5/ios" data-tocid="IPH5A0B5B9C5" href="https://support.apple.com/guide/iphone/wake-and-unlock-iph5a0b5b9c5/ios" id="toc-item-IPH5A0B5B9C5">
# <span class="name">Wake and unlock</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/set-up-cellular-service-iph3f11fba92/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Set up cellular service" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/set-up-cellular-service-iph3f11fba92/ios" data-tocid="IPH3F11FBA92" href="https://support.apple.com/guide/iphone/set-up-cellular-service-iph3f11fba92/ios" id="toc-item-IPH3F11FBA92">
# <span class="name">Set up cellular service</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/use-dual-sim-iph9c5776d3c/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Use Dual SIM" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/use-dual-sim-iph9c5776d3c/ios" data-tocid="IPH9C5776D3C" href="https://support.apple.com/guide/iphone/use-dual-sim-iph9c5776d3c/ios" id="toc-item-IPH9C5776D3C">
# <span class="name">Use Dual SIM</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/connect-to-the-internet-iphd1cf4268/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Connect to the internet" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/connect-to-the-internet-iphd1cf4268/ios" data-tocid="IPHD1CF4268" href="https://support.apple.com/guide/iphone/connect-to-the-internet-iphd1cf4268/ios" id="toc-item-IPHD1CF4268">
# <span class="name">Connect to the internet</span>
# </a>
# </li>
# <li>
#
# <ul class="non-leaf-node-children" id="node-children-IPH849BD2870">
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/apple-id-settings-iph76e54c61e/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Apple ID settings" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/apple-id-settings-iph76e54c61e/ios" data-tocid="IPH76E54C61E" href="https://support.apple.com/guide/iphone/apple-id-settings-iph76e54c61e/ios" id="toc-item-IPH76E54C61E">
# <span class="name">Apple ID settings</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/turn-icloud-features-on-or-off-iphde0f868fd/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Turn iCloud features on or off" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/turn-icloud-features-on-or-off-iphde0f868fd/ios" data-tocid="IPHDE0F868FD" href="https://support.apple.com/guide/iphone/turn-icloud-features-on-or-off-iphde0f868fd/ios" id="toc-item-IPHDE0F868FD">
# <span class="name">Turn iCloud features on or off</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/subscribe-to-icloud-iphe9af54d75/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Subscribe to iCloud+" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/subscribe-to-icloud-iphe9af54d75/ios" data-tocid="IPHE9AF54D75" href="https://support.apple.com/guide/iphone/subscribe-to-icloud-iphe9af54d75/ios" id="toc-item-IPHE9AF54D75">
# <span class="name">Subscribe to iCloud+</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/find-settings-iph079e1fe9d/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Find settings" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/find-settings-iph079e1fe9d/ios" data-tocid="IPH079E1FE9D" href="https://support.apple.com/guide/iphone/find-settings-iph079e1fe9d/ios" id="toc-item-IPH079E1FE9D">
# <span class="name">Find settings</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/set-up-mail-contacts-and-calendar-accounts-ipha0d932e96/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Set up mail, contacts, and calendar accounts" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/set-up-mail-contacts-and-calendar-accounts-ipha0d932e96/ios" data-tocid="IPHA0D932E96" href="https://support.apple.com/guide/iphone/set-up-mail-contacts-and-calendar-accounts-ipha0d932e96/ios" id="toc-item-IPHA0D932E96">
# <span class="name">Set up mail, contacts, and calendar accounts</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/learn-the-meaning-of-the-status-icons-iphef7bb57dc/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Learn the meaning of the status icons" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/learn-the-meaning-of-the-status-icons-iphef7bb57dc/ios" data-tocid="IPHEF7BB57DC" href="https://support.apple.com/guide/iphone/learn-the-meaning-of-the-status-icons-iphef7bb57dc/ios" id="toc-item-IPHEF7BB57DC">
# <span class="name">Learn the meaning of the status icons</span>
# </a>
# </li>
# <li>
#
# <ul class="non-leaf-node-children" id="node-children-IPH14E4A773C">
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/charge-the-battery-iph63eecc618/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Charge the battery" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/charge-the-battery-iph63eecc618/ios" data-tocid="IPH63EECC618" href="https://support.apple.com/guide/iphone/charge-the-battery-iph63eecc618/ios" id="toc-item-IPH63EECC618">
# <span class="name">Charge the battery</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/show-the-battery-percentage-iph4747a74a9/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Show the battery percentage" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/show-the-battery-percentage-iph4747a74a9/ios" data-tocid="IPH4747A74A9" href="https://support.apple.com/guide/iphone/show-the-battery-percentage-iph4747a74a9/ios" id="toc-item-IPH4747A74A9">
# <span class="name">Show the battery percentage</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/check-battery-health-and-usage-iphd453d043a/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Check battery health and usage" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/check-battery-health-and-usage-iphd453d043a/ios" data-tocid="IPHD453D043A" href="https://support.apple.com/guide/iphone/check-battery-health-and-usage-iphd453d043a/ios" id="toc-item-IPHD453D043A">
# <span class="name">Check battery health and usage</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/download-or-bookmark-the-user-guide-iph3bf43c08/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Download or bookmark the user guide" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/download-or-bookmark-the-user-guide-iph3bf43c08/ios" data-tocid="IPH3BF43C08" href="https://support.apple.com/guide/iphone/download-or-bookmark-the-user-guide-iph3bf43c08/ios" id="toc-item-IPH3BF43C08">
# <span class="name">Download or bookmark the user guide</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
#
# <ul class="non-leaf-node-children" id="node-children-IPH3C511601">
# <li>
#
# <ul class="non-leaf-node-children" id="node-children-IPH75BBD35EE">
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/learn-basic-gestures-iph75e97af9b/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Learn basic gestures" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/learn-basic-gestures-iph75e97af9b/ios" data-tocid="IPH75E97AF9B" href="https://support.apple.com/guide/iphone/learn-basic-gestures-iph75e97af9b/ios" id="toc-item-IPH75E97AF9B">
# <span class="name">Learn basic gestures</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/learn-gestures-for-iphone-models-with-face-id-iphfdf164cac/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Learn gestures for iPhone models with Face ID" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/learn-gestures-for-iphone-models-with-face-id-iphfdf164cac/ios" data-tocid="IPHFDF164CAC" href="https://support.apple.com/guide/iphone/learn-gestures-for-iphone-models-with-face-id-iphfdf164cac/ios" id="toc-item-IPHFDF164CAC">
# <span class="name">Learn gestures for iPhone models with Face ID</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/adjust-the-volume-iphb71f9b54d/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Adjust the volume" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/adjust-the-volume-iphb71f9b54d/ios" data-tocid="IPHB71F9B54D" href="https://support.apple.com/guide/iphone/adjust-the-volume-iphb71f9b54d/ios" id="toc-item-IPHB71F9B54D">
# <span class="name">Adjust the volume</span>
# </a>
# </li>
# <li>
#
# <ul class="non-leaf-node-children" id="node-children-IPH5F3B0F791">
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/open-apps-iphca3d8b4e3/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Open apps" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/open-apps-iphca3d8b4e3/ios" data-tocid="IPHCA3D8B4E3" href="https://support.apple.com/guide/iphone/open-apps-iphca3d8b4e3/ios" id="toc-item-IPHCA3D8B4E3">
# <span class="name">Open apps</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/find-your-apps-in-app-library-iph87abad19a/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Find your apps in App Library" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/find-your-apps-in-app-library-iph87abad19a/ios" data-tocid="IPH87ABAD19A" href="https://support.apple.com/guide/iphone/find-your-apps-in-app-library-iph87abad19a/ios" id="toc-item-IPH87ABAD19A">
# <span class="name">Find your apps in App Library</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/switch-between-open-apps-iph1a1f981ad/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Switch between open apps" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/switch-between-open-apps-iph1a1f981ad/ios" data-tocid="IPH1A1F981AD" href="https://support.apple.com/guide/iphone/switch-between-open-apps-iph1a1f981ad/ios" id="toc-item-IPH1A1F981AD">
# <span class="name">Switch between open apps</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/quit-and-reopen-an-app-iph83bfec492/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Quit and reopen an app" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/quit-and-reopen-an-app-iph83bfec492/ios" data-tocid="IPH83BFEC492" href="https://support.apple.com/guide/iphone/quit-and-reopen-an-app-iph83bfec492/ios" id="toc-item-IPH83BFEC492">
# <span class="name">Quit and reopen an app</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
#
# <ul class="non-leaf-node-children" id="node-children-IPH3C5104D5">
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/dictate-text-iph2c0651d2/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Dictate text" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/dictate-text-iph2c0651d2/ios" data-tocid="IPH2C0651D2" href="https://support.apple.com/guide/iphone/dictate-text-iph2c0651d2/ios" id="toc-item-IPH2C0651D2">
# <span class="name">Dictate text</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/type-with-the-onscreen-keyboard-iph3c50f96e/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Type with the onscreen keyboard" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/type-with-the-onscreen-keyboard-iph3c50f96e/ios" data-tocid="IPH3C50F96E" href="https://support.apple.com/guide/iphone/type-with-the-onscreen-keyboard-iph3c50f96e/ios" id="toc-item-IPH3C50F96E">
# <span class="name">Type with the onscreen keyboard</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/select-and-edit-text-iph1a9cae52c/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Select and edit text" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/select-and-edit-text-iph1a9cae52c/ios" data-tocid="IPH1A9CAE52C" href="https://support.apple.com/guide/iphone/select-and-edit-text-iph1a9cae52c/ios" id="toc-item-IPH1A9CAE52C">
# <span class="name">Select and edit text</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/use-predictive-text-iphd4ea90231/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Use predictive text" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/use-predictive-text-iphd4ea90231/ios" data-tocid="IPHD4EA90231" href="https://support.apple.com/guide/iphone/use-predictive-text-iphd4ea90231/ios" id="toc-item-IPHD4EA90231">
# <span class="name">Use predictive text</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/use-text-replacements-iph6d01d862/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Use text replacements" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/use-text-replacements-iph6d01d862/ios" data-tocid="IPH6D01D862" href="https://support.apple.com/guide/iphone/use-text-replacements-iph6d01d862/ios" id="toc-item-IPH6D01D862">
# <span class="name">Use text replacements</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/add-or-change-keyboards-iph73b71eb/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Add or change keyboards" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/add-or-change-keyboards-iph73b71eb/ios" data-tocid="IPH73B71EB" href="https://support.apple.com/guide/iphone/add-or-change-keyboards-iph73b71eb/ios" id="toc-item-IPH73B71EB">
# <span class="name">Add or change keyboards</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/multitask-with-picture-in-picture-iphcc3587b5d/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Multitask with Picture in Picture" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/multitask-with-picture-in-picture-iphcc3587b5d/ios" data-tocid="IPHCC3587B5D" href="https://support.apple.com/guide/iphone/multitask-with-picture-in-picture-iphcc3587b5d/ios" id="toc-item-IPHCC3587B5D">
# <span class="name">Multitask with Picture in Picture</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/access-features-from-the-lock-screen-iphcd5c65ccf/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Access features from the Lock Screen" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/access-features-from-the-lock-screen-iphcd5c65ccf/ios" data-tocid="IPHCD5C65CCF" href="https://support.apple.com/guide/iphone/access-features-from-the-lock-screen-iphcd5c65ccf/ios" id="toc-item-IPHCD5C65CCF">
# <span class="name">Access features from the Lock Screen</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/view-activities-in-the-dynamic-island-iph28f50d10d/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="View activities in the Dynamic Island" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/view-activities-in-the-dynamic-island-iph28f50d10d/ios" data-tocid="IPH28F50D10D" href="https://support.apple.com/guide/iphone/view-activities-in-the-dynamic-island-iph28f50d10d/ios" id="toc-item-IPH28F50D10D">
# <span class="name">View activities in the Dynamic Island</span>
# </a>
# </li>
# <li>
# ...
# <span class="name">Restore all content from a backup</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/restore-purchased-and-deleted-items-iphfe205f2e5/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Restore purchased and deleted items" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/restore-purchased-and-deleted-items-iphfe205f2e5/ios" data-tocid="IPHFE205F2E5" href="https://support.apple.com/guide/iphone/restore-purchased-and-deleted-items-iphfe205f2e5/ios" id="toc-item-IPHFE205F2E5">
# <span class="name">Restore purchased and deleted items</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/sell-give-away-or-trade-in-your-iphone-iph415eb3fe5/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Sell, give away, or trade in your iPhone" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/sell-give-away-or-trade-in-your-iphone-iph415eb3fe5/ios" data-tocid="IPH415EB3FE5" href="https://support.apple.com/guide/iphone/sell-give-away-or-trade-in-your-iphone-iph415eb3fe5/ios" id="toc-item-IPH415EB3FE5">
# <span class="name">Sell, give away, or trade in your iPhone</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/erase-iphone-iph7a2a9399b/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Erase iPhone" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/erase-iphone-iph7a2a9399b/ios" data-tocid="IPH7A2A9399B" href="https://support.apple.com/guide/iphone/erase-iphone-iph7a2a9399b/ios" id="toc-item-IPH7A2A9399B">
# <span class="name">Erase iPhone</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/install-or-remove-configuration-profiles-iph6c493b19/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Install or remove configuration profiles" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/install-or-remove-configuration-profiles-iph6c493b19/ios" data-tocid="IPH6C493B19" href="https://support.apple.com/guide/iphone/install-or-remove-configuration-profiles-iph6c493b19/ios" id="toc-item-IPH6C493B19">
# <span class="name">Install or remove configuration profiles</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
#
# <ul class="non-leaf-node-children" id="node-children-IPH3E504EE8">
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/important-safety-information-iph301fc905/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Important safety information" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/important-safety-information-iph301fc905/ios" data-tocid="IPH301FC905" href="https://support.apple.com/guide/iphone/important-safety-information-iph301fc905/ios" id="toc-item-IPH301FC905">
# <span class="name">Important safety information</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/important-handling-information-iphbbe12ba1/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Important handling information" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/important-handling-information-iphbbe12ba1/ios" data-tocid="IPHBBE12BA1" href="https://support.apple.com/guide/iphone/important-handling-information-iphbbe12ba1/ios" id="toc-item-IPHBBE12BA1">
# <span class="name">Important handling information</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/find-more-resources-for-software-and-service-iph3e504a1f/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Find more resources for software and service" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/find-more-resources-for-software-and-service-iph3e504a1f/ios" data-tocid="IPH3E504A1F" href="https://support.apple.com/guide/iphone/find-more-resources-for-software-and-service-iph3e504a1f/ios" id="toc-item-IPH3E504A1F">
# <span class="name">Find more resources for software and service</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/fcc-compliance-statement-iphf53e635fe/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="FCC compliance statement" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/fcc-compliance-statement-iphf53e635fe/ios" data-tocid="IPHF53E635FE" href="https://support.apple.com/guide/iphone/fcc-compliance-statement-iphf53e635fe/ios" id="toc-item-IPHF53E635FE">
# <span class="name">FCC compliance statement</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/ised-canada-compliance-statement-iph0f8cc7f18/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="ISED Canada compliance statement" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/ised-canada-compliance-statement-iph0f8cc7f18/ios" data-tocid="IPH0F8CC7F18" href="https://support.apple.com/guide/iphone/ised-canada-compliance-statement-iph0f8cc7f18/ios" id="toc-item-IPH0F8CC7F18">
# <span class="name">ISED Canada compliance statement</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/ultra-wideband-information-iph771fd0aad/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Ultra Wideband information" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/ultra-wideband-information-iph771fd0aad/ios" data-tocid="IPH771FD0AAD" href="https://support.apple.com/guide/iphone/ultra-wideband-information-iph771fd0aad/ios" id="toc-item-IPH771FD0AAD">
# <span class="name">Ultra Wideband information</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/class-1-laser-information-iph0d0b537f0/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Class 1 Laser information" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/class-1-laser-information-iph0d0b537f0/ios" data-tocid="IPH0D0B537F0" href="https://support.apple.com/guide/iphone/class-1-laser-information-iph0d0b537f0/ios" id="toc-item-IPH0D0B537F0">
# <span class="name">Class 1 Laser information</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/apple-and-the-environment-iph3e50444a/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Apple and the environment" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/apple-and-the-environment-iph3e50444a/ios" data-tocid="IPH3E50444A" href="https://support.apple.com/guide/iphone/apple-and-the-environment-iph3e50444a/ios" id="toc-item-IPH3E50444A">
# <span class="name">Apple and the environment</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/disposal-and-recycling-information-iph3e5055a8/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Disposal and recycling information" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/disposal-and-recycling-information-iph3e5055a8/ios" data-tocid="IPH3E5055A8" href="https://support.apple.com/guide/iphone/disposal-and-recycling-information-iph3e5055a8/ios" id="toc-item-IPH3E5055A8">
# <span class="name">Disposal and recycling information</span>
# </a>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/unauthorized-modification-of-ios-iph9385bb26a/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Unauthorized modification of iOS" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/unauthorized-modification-of-ios-iph9385bb26a/ios" data-tocid="IPH9385BB26A" href="https://support.apple.com/guide/iphone/unauthorized-modification-of-ios-iph9385bb26a/ios" id="toc-item-IPH9385BB26A">
# <span class="name">Unauthorized modification of iOS</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
# <a class="toc-item" data-ajax-endpoint="https://support.apple.com/guide/iphone/copyright-iph3e5c0810/ios" data-ss-analytics-event="acs.link_click" data-ss-analytics-link-component_name="iPhone User Guide" data-ss-analytics-link-component_type="toc list" data-ss-analytics-link-text="Copyright" data-ss-analytics-link-url="https://support.apple.com/guide/iphone/copyright-iph3e5c0810/ios" data-tocid="IPH3E5C0810" href="https://support.apple.com/guide/iphone/copyright-iph3e5c0810/ios" id="toc-item-IPH3E5C0810">
# <span class="name">Copyright</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div id="article-section-wrapper">
# <div id="article-section" role="presentation">
# <div class="AppleTopic apd-topic dark-mode-enabled book book-content">
# <div><body class="AppleTopic apd-topic dark-mode-enabled" data-designversion="2" data-istaskopen="true" dir="ltr" id="iphf33a514c9" lang="en"><a name="iphf33a514c9"></a><h1>Intro to CarPlay and iPhone</h1><p>Connect your iPhone to CarPlay to get turn-by-turn directions, make phone calls, listen to music, check your calendar, and more—all from your vehicle’s display.</p><figure><img alt="CarPlay Dashboard showing icons for Maps, Music, and Messages on the left, a map showing a driving route in the middle, and three items stacked on the right. The top item on the right shows shows the driving time to a location. The middle item shows media playback controls. The lower item indicates an upcoming calendar appointment." height="224" originalimagename="Art/S3505_carPlayDashboard_iPhone.png" src="https://help.apple.com/assets/640A52196275DE31D4371B5E/640A52226275DE31D4371B8B/en_US/53782ec8d93f387dc990ec191c45061d.png" width="399"/></figure><div class="Alert"><p class="Note"><em>Note: </em>CarPlay isn’t available in all countries or regions (see the <a class="URL" href="https://www.apple.com/ios/feature-availability/#applecarplay-applecarplay">iOS and iPadOS Feature Availability website</a>).</p></div><p>CarPlay is available on select automobiles (see the <a class="URL" href="https://www.apple.com/ios/carplay/available-models">CarPlay Available Models website</a>) and on select aftermarket navigation systems.</p><div class="Alert"><p class="Warning"><strong>WARNING: </strong>For important information about avoiding distractions that could lead to dangerous situations, see <a class="xRef AppleTopic" href="https://support.apple.com/guide/iphone/important-safety-information-iph301fc905/16.0/ios/16.0">Important safety information for iPhone</a>.</p></div></body></div>
# </div>
# </div>
# </div>
# <div id="aside-hidden-content">
# <div class="main">
# </div>
# </div>
# <div id="helpful-rating-wrapper">
# <div class="ratings okapi-enabled" id="helpful">
# <div class="show" id="question-state">
# <fieldset>
# <legend>
# <span id="okapi-a">Helpful?</span>
# </legend>
# <div class="helpful-btn-grp">
#
#
# </div>
# </fieldset>
# </div>
# <div class="form-element form-textbox-labelbelow hide" id="feedback-state">
# <form autocomplete="off">
# <input id="form-counter-error-message" type="hidden" value="Maximum character limit is 250."/>
# <label data-no-label="Thanks for letting us know." data-yes-label="We’re glad this article helped." id="feedback-label"></label>
# <div class="form-element form-textbox-labelbelow" id="feedback">
# <div class="textarea-wrapper">
# <span aria-hidden="true" class="form-label" id="optional_label"></span>
# <div>
# <textarea aria-describedby="char_limit_counter" aria-labelledby="optional_label" class="form-textbox form-textbox-textarea form-counter-textarea form-textbox-entered" data-max-length="250" data-no-placeholder="How can we make this article more helpful? (Optional)" data-yes-placeholder="Anything else you’d like us to know? (Optional)"></textarea>
# <div class="form-textbox-counter" id="char_limit_counter">
# <span class="visuallyhidden" id="char-limit-message">Character limit:</span>
# <span class="form-counter">250</span>
# </div>
# </div>
# </div>
# <label htmlfor="feedback-note">Please don’t include any personal information in your comment.</label>
# <div class="form-message-wrapper">
# <span class="form-message">Maximum character limit is 250.</span>
# </div>
#
# </div>
# </form>
# </div>
# <div class="hide" id="rating-done">
#         Thanks for your feedback.
#     </div>
# <div class="show" id="results-helpful">
# </div>
# </div>
# </div>
# <div id="article-pagination-wrapper">
#
# </div>
# </div>
# <div class="footer-wrapper">
# <footer aria-labelledby="ac-gf-label" class="js no-touch svg no-ie7 no-ie8 footer-global" data-analytics-region="global footer" dir="ltr" id="ac-globalfooter" lang="en-us" role="contentinfo">
# <div class="ac-gf-content">
# <h2 class="ac-gf-label" id="ac-gf-label">Apple Footer</h2>
#
# <section class="ac-gf-footer" typeof="Organization" vocab="https://schema.org/"> <div class="ac-gf-footer-shop" x-ms-format-detection="none"></div> <div class="ac-gf-footer-locale"> <a aria-label="United States. Choose your country or region" class="ac-gf-footer-locale-link" href="https://support.apple.com/guide/iphone/intro-to-carplay-iphf33a514c9/ios/localeselector" title="Choose your country or region">United States</a> </div> <div class="ac-gf-footer-legal"> <div class="ac-gf-footer-legal-copyright">Copyright © 2023 Apple Inc. All rights reserved.</div> <div class="ac-gf-footer-legal-links"> <a class="ac-gf-footer-legal-link analytics-exitlink" href="https://www.apple.com/legal/privacy/en-ww/">Privacy Policy</a> <a class="ac-gf-footer-legal-link analytics-exitlink" href="https://www.apple.com/legal/internet-services/terms/site.html">Terms of Use</a> <a class="ac-gf-footer-legal-link analytics-exitlink" href="https://www.apple.com/shop/goto/help/sales_refunds">Sales and Refunds</a> <a class="ac-gf-footer-legal-link" href="https://www.apple.com/sitemap/">Site Map</a></div> </div> <meta content="Apple" property="name"/> <meta content="1-800-692-7753" property="telephone"/> </section>
# </div>
# </footer>
# </div>
#
#
#
#
#
#
# <div aria-live="polite" class="a11y" id="apd-aria-live-region" role="status"></div>
# </link></body>
